# %% [markdown]
# # Stastic Notebook
# This is the notebook for our experiment’s data processing and statistics. It covers everything from handling `.fasta` files generated by our model to output statistical summaries — including **median/mean** results for **single seed** experiments and **median/mean** across **multiple seeds**. Please make sure to check and adjust the file paths accordingly.
# - Process `.fasta` files to `.txt` files.
# - Cauculate the single seed stastic data.
# - Cauculate the multiple seed stastic data.

# %%
import numpy as np
import os
import re
import glob
from pathlib import Path
from statistics import median
from typing import List

# %%
#####Process fasta files and generate the data txt files that we need#####
def parse_fasta_file(fasta_path):
    """
    Parse a single FASTA file to extract the input sequence length and metrics for 16 samples
    
    Returns:
    - input_length: Length of the input sequence
    - median_metrics: Median metrics for 16 samples {perplexity, recovery, edit_dist, sc_score}
    """
    try:
        with open(fasta_path, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Split different sequence blocks
        sequences = content.strip().split('>')
        sequences = [seq.strip() for seq in sequences if seq.strip()]
        
        input_length = 0
        sample_metrics = []
        
        for seq_block in sequences:
            lines = seq_block.strip().split('\n')
            if not lines:
                continue
            
            header = lines[0]
            sequence_lines = lines[1:]
            
            # Process input sequence
            if 'input_sequence' in header:
                # Combine all sequence lines and calculate length
                sequence = ''.join(sequence_lines).replace(' ', '').replace('\n', '')
                input_length = len(sequence)
                print(f"  Input sequence length: {input_length}")
            
            # Process sample sequence
            elif 'sample=' in header:
                # Extract metrics using regular expressions
                perplexity_match = re.search(r'perplexity=([0-9.]+)', header)
                recovery_match = re.search(r'recovery=([0-9.]+)', header)
                edit_dist_match = re.search(r'edit_dist=([0-9.]+)', header)
                sc_score_match = re.search(r'sc_score=([0-9.]+)', header)
                
                if all([perplexity_match, recovery_match, edit_dist_match, sc_score_match]):
                    metrics = {
                        'perplexity': float(perplexity_match.group(1)),
                        'recovery': float(recovery_match.group(1)),
                        'edit_dist': float(edit_dist_match.group(1)),
                        'sc_score': float(sc_score_match.group(1))
                    }
                    sample_metrics.append(metrics)
        
        # Calculate medians
        if sample_metrics:
            median_metrics = {
                'perplexity': median(m['perplexity'] for m in sample_metrics),
                'recovery': median(m['recovery'] for m in sample_metrics),
                'edit_dist': median(m['edit_dist'] for m in sample_metrics),
                'sc_score': median(m['sc_score'] for m in sample_metrics)
            }
            print(f"  Found {len(sample_metrics)} samples")
            print(f"  Median metrics: perplexity={median_metrics['perplexity']:.4f}, recovery={median_metrics['recovery']:.4f}, edit_dist={median_metrics['edit_dist']:.4f}, sc_score={median_metrics['sc_score']:.4f}")
        else:
            print("  Warning: No valid sample metrics found")
            median_metrics = None
        
        return input_length, median_metrics
        
    except Exception as e:
        print(f"  Error: Exception occurred while processing file: {e}")
        return 0, None

def process_all_fasta_files(input_dir, output_file):
    """
    Process all FASTA files in the specified directory
    """
    print("=== FASTA File Processing Script ===")
    
    # Check input directory
    if not os.path.exists(input_dir):
        print(f"Error: Input directory does not exist: {input_dir}")
        return
    
    # Create output directory
    output_dir = os.path.dirname(output_file)
    if output_dir:
        os.makedirs(output_dir, exist_ok=True)
        print(f"Output directory: {output_dir}")
    
    # Find all FASTA files
    fasta_pattern = os.path.join(input_dir, "*.fasta")
    fasta_files = glob.glob(fasta_pattern)
    
    if not fasta_files:
        print(f"Warning: No .fasta files found in {input_dir}")
        return
    
    print(f"Found {len(fasta_files)} FASTA files")
    
    # Store processing results
    results = []
    processed_count = 0
    failed_count = 0
    
    # Process each FASTA file
    for i, fasta_file in enumerate(sorted(fasta_files), 1):
        filename = os.path.basename(fasta_file)
        print(f"\n[{i}/{len(fasta_files)}] Processing file: {filename}")
        
        input_length, median_metrics = parse_fasta_file(fasta_file)
        
        if input_length > 0 and median_metrics is not None:
            # Format result
            result_line = f"{input_length} {median_metrics['perplexity']:.4f} {median_metrics['recovery']:.4f} {median_metrics['edit_dist']:.4f} {median_metrics['sc_score']:.4f}"
            results.append(result_line)
            processed_count += 1
            print(f"  ✓ Processed successfully")
        else:
            print(f"  ✗ Processing failed")
            failed_count += 1
    
    # Save results
    if results:
        try:
            with open(output_file, 'w', encoding='utf-8') as f:
                for result in results:
                    f.write(result + '\n')
            
            print(f"\n=== Processing Completed ===")
            print(f"Total files: {len(fasta_files)}")
            print(f"Successfully processed: {processed_count}")
            print(f"Failed: {failed_count}")
            print(f"Results saved to: {output_file}")
            
            # Show preview of first few lines
            print(f"\nResults preview (first 5 lines):")
            for i, result in enumerate(results[:5]):
                print(f"  {result}")
            if len(results) > 5:
                print(f"  ... (total {len(results)} lines)")
                
        except Exception as e:
            print(f"Error saving file: {e}")
    else:
        print("No successfully processed data, unable to generate output file")

def validate_output_format(output_file):
    """
    Validate the format of the output file
    """
    if not os.path.exists(output_file):
        print("Output file does not exist")
        return
    
    print(f"\n=== Validate Output Format ===")
    try:
        with open(output_file, 'r', encoding='utf-8') as f:
            lines = f.readlines()
        
        print(f"Total lines: {len(lines)}")
        
        for i, line in enumerate(lines[:3], 1):  # Check first 3 lines
            parts = line.strip().split()
            if len(parts) == 5:
                length = int(parts[0])
                perplexity = float(parts[1])
                recovery = float(parts[2])
                edit_dist = float(parts[3])
                sc_score = float(parts[4])
                print(f"Line {i}: length={length}, perplexity={perplexity}, recovery={recovery}, edit_dist={edit_dist}, sc_score={sc_score}")
            else:
                print(f"Line {i} format error: {line.strip()}")
    
    except Exception as e:
        print(f"Error during validation: {e}")

def main():
    """
    Main function
    """
    # Set input and output paths
    input_directory = "./testfasta/fullatten03_s4"
    output_filepath = "./data/fullatten03_s4.txt"

    # Process all FASTA files
    process_all_fasta_files(input_directory, output_filepath)
    
    # Validate output format
    validate_output_format(output_filepath)

if __name__ == "__main__":
    main()
# Out:
# === FASTA File Processing Script ===
# Output directory: ./data
# Found 612 FASTA files
#
# [1/612] Processing file: 1EFW_1_C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.2319, recovery=0.7381, edit_dist=16.0000, sc_score=0.6968
#   ✓ Processed successfully
#
# [2/612] Processing file: 1EFW_1_D.fasta
#   Input sequence length: 63
#   Found 15 samples
#   Median metrics: perplexity=1.1531, recovery=0.7619, edit_dist=15.0000, sc_score=0.9318
#   ✓ Processed successfully
#
# [3/612] Processing file: 1EHT_3_A.fasta
#   Input sequence length: 33
#   Found 16 samples
#   Median metrics: perplexity=1.1933, recovery=0.5312, edit_dist=15.0000, sc_score=0.6284
#   ✓ Processed successfully
#
# [4/612] Processing file: 1EHZ_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1919, recovery=0.6935, edit_dist=17.0000, sc_score=0.2216
#   ✓ Processed successfully
#
# [5/612] Processing file: 1EVV_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1978, recovery=0.7339, edit_dist=15.0000, sc_score=0.3626
#   ✓ Processed successfully
#
# [6/612] Processing file: 1FCW_1_A.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.2077, recovery=0.7097, edit_dist=17.5000, sc_score=0.3673
#   ✓ Processed successfully
#
# [7/612] Processing file: 1FCW_1_B.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.2077, recovery=0.7097, edit_dist=17.5000, sc_score=0.3673
#   ✓ Processed successfully
#
# [8/612] Processing file: 1FCW_1_C.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.2001, recovery=0.7097, edit_dist=18.0000, sc_score=0.3725
#   ✓ Processed successfully
#
# [9/612] Processing file: 1FCW_1_D.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.2077, recovery=0.7097, edit_dist=17.5000, sc_score=0.3673
#   ✓ Processed successfully
#
# [10/612] Processing file: 1FCW_1_E.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.1862, recovery=0.7016, edit_dist=18.0000, sc_score=0.3910
#   ✓ Processed successfully
#
# [11/612] Processing file: 1HMH_1_A.fasta
#   Input sequence length: 34
#   Found 4 samples
#   Median metrics: perplexity=2.3216, recovery=0.3529, edit_dist=15.5000, sc_score=0.2842
#   ✓ Processed successfully
#
# [12/612] Processing file: 1HMH_1_C.fasta
#   Input sequence length: 34
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [13/612] Processing file: 1HMH_1_E.fasta
#   Input sequence length: 34
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [14/612] Processing file: 1J7T_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1386, recovery=0.7143, edit_dist=12.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [15/612] Processing file: 1JGO_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2086, recovery=0.7339, edit_dist=15.0000, sc_score=0.4859
#   ✓ Processed successfully
#
# [16/612] Processing file: 1JGO_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2242, recovery=0.6774, edit_dist=19.0000, sc_score=0.3698
#   ✓ Processed successfully
#
# [17/612] Processing file: 1JGP_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2086, recovery=0.7339, edit_dist=15.0000, sc_score=0.4859
#   ✓ Processed successfully
#
# [18/612] Processing file: 1JGP_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2242, recovery=0.6774, edit_dist=19.0000, sc_score=0.3698
#   ✓ Processed successfully
#
# [19/612] Processing file: 1JGQ_1_B.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2086, recovery=0.7339, edit_dist=15.0000, sc_score=0.4859
#   ✓ Processed successfully
#
# [20/612] Processing file: 1JGQ_1_C.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2242, recovery=0.6774, edit_dist=19.0000, sc_score=0.3698
#   ✓ Processed successfully
#
# [21/612] Processing file: 1LC4_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1020, recovery=0.5952, edit_dist=17.0000, sc_score=0.8493
#   ✓ Processed successfully
#
# [22/612] Processing file: 1MME_1_B-A.fasta
#   Input sequence length: 41
#   Found 1 samples
#   Median metrics: perplexity=1.3412, recovery=0.4615, edit_dist=18.0000, sc_score=0.1250
#   ✓ Processed successfully
#
# [23/612] Processing file: 1MME_1_D-C.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [24/612] Processing file: 1MWL_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1479, recovery=0.6190, edit_dist=14.0000, sc_score=0.8474
#   ✓ Processed successfully
#
# [25/612] Processing file: 1NLC_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2464, recovery=0.3409, edit_dist=26.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [26/612] Processing file: 1O15_1_A.fasta
#   Input sequence length: 33
#   Found 16 samples
#   Median metrics: perplexity=1.1162, recovery=0.7812, edit_dist=8.0000, sc_score=0.7960
#   ✓ Processed successfully
#
# [27/612] Processing file: 1O3Z_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2450, recovery=0.3636, edit_dist=26.5000, sc_score=0.9072
#   ✓ Processed successfully
#
# [28/612] Processing file: 1O9M_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2686, recovery=0.4625, edit_dist=19.0000, sc_score=0.8569
#   ✓ Processed successfully
#
# [29/612] Processing file: 1RRR_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1406, recovery=0.1667, edit_dist=8.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [30/612] Processing file: 1SZ1_1_E.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.1871, recovery=0.6885, edit_dist=17.0000, sc_score=0.2632
#   ✓ Processed successfully
#
# [31/612] Processing file: 1SZ1_1_F.fasta
#   Input sequence length: 62
#   Found 13 samples
#   Median metrics: perplexity=1.1805, recovery=0.6721, edit_dist=18.0000, sc_score=0.3187
#   ✓ Processed successfully
#
# [32/612] Processing file: 1TFY_1_G-J.fasta
#   Input sequence length: 19
#   Found 16 samples
#   Median metrics: perplexity=1.1918, recovery=0.4118, edit_dist=7.0000, sc_score=0.9225
#   ✓ Processed successfully
#
# [33/612] Processing file: 1TN1_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1689, recovery=0.7419, edit_dist=14.0000, sc_score=0.5481
#   ✓ Processed successfully
#
# [34/612] Processing file: 1TN2_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1689, recovery=0.7419, edit_dist=14.0000, sc_score=0.5481
#   ✓ Processed successfully
#
# [35/612] Processing file: 1TRA_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1754, recovery=0.7419, edit_dist=16.0000, sc_score=0.5262
#   ✓ Processed successfully
#
# [36/612] Processing file: 1TTT_1_D.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1564, recovery=0.7823, edit_dist=13.0000, sc_score=0.3725
#   ✓ Processed successfully
#
# [37/612] Processing file: 1TTT_1_E.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1711, recovery=0.7823, edit_dist=13.0000, sc_score=0.4079
#   ✓ Processed successfully
#
# [38/612] Processing file: 1TTT_1_F.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1452, recovery=0.7903, edit_dist=13.0000, sc_score=0.7910
#   ✓ Processed successfully
#
# [39/612] Processing file: 1WVD_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2101, recovery=0.4545, edit_dist=24.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [40/612] Processing file: 1WZ2_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2581, recovery=0.5682, edit_dist=36.0000, sc_score=0.6652
#   ✓ Processed successfully
#
# [41/612] Processing file: 1WZ2_1_D.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2617, recovery=0.5682, edit_dist=35.0000, sc_score=0.6475
#   ✓ Processed successfully
#
# [42/612] Processing file: 1XJR_1_A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2208, recovery=0.4674, edit_dist=23.0000, sc_score=0.4348
#   ✓ Processed successfully
#
# [43/612] Processing file: 1XMQ_1_X-W.fasta
#   Input sequence length: 14
#   Found 15 samples
#   Median metrics: perplexity=1.0696, recovery=0.3333, edit_dist=9.0000, sc_score=0.4789
#   ✓ Processed successfully
#
# [44/612] Processing file: 1XPF_1_A-B.fasta
#   Input sequence length: 46
#   Found 7 samples
#   Median metrics: perplexity=1.1602, recovery=0.4545, edit_dist=23.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [45/612] Processing file: 1Y6S_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2946, recovery=0.4773, edit_dist=21.5000, sc_score=0.9205
#   ✓ Processed successfully
#
# [46/612] Processing file: 1Y6T_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2462, recovery=0.3522, edit_dist=26.0000, sc_score=0.8519
#   ✓ Processed successfully
#
# [47/612] Processing file: 1Y73_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2045, recovery=0.3636, edit_dist=26.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [48/612] Processing file: 1Y95_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2692, recovery=0.3864, edit_dist=25.0000, sc_score=0.8939
#   ✓ Processed successfully
#
# [49/612] Processing file: 1Y99_1_A-B.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2748, recovery=0.3409, edit_dist=27.5000, sc_score=0.8939
#   ✓ Processed successfully
#
# [50/612] Processing file: 1YFG_1_A.fasta
#   Input sequence length: 64
#   Found 16 samples
#   Median metrics: perplexity=1.2216, recovery=0.5469, edit_dist=26.5000, sc_score=0.8592
#   ✓ Processed successfully
#
# [51/612] Processing file: 1YRJ_1_A-B.fasta
#   Input sequence length: 45
#   Found 16 samples
#   Median metrics: perplexity=1.1303, recovery=0.6744, edit_dist=16.0000, sc_score=0.8800
#   ✓ Processed successfully
#
# [52/612] Processing file: 299D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [53/612] Processing file: 2B8S_1_A-B.fasta
#   Input sequence length: 46
#   Found 2 samples
#   Median metrics: perplexity=1.1346, recovery=0.4773, edit_dist=23.0000, sc_score=0.9603
#   ✓ Processed successfully
#
# [54/612] Processing file: 2BE0_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1485, recovery=0.6667, edit_dist=14.0000, sc_score=0.8799
#   ✓ Processed successfully
#
# [55/612] Processing file: 2BEE_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1523, recovery=0.6667, edit_dist=14.0000, sc_score=0.8157
#   ✓ Processed successfully
#
# [56/612] Processing file: 2DR5_1_B.fasta
#   Input sequence length: 32
#   Found 16 samples
#   Median metrics: perplexity=1.1523, recovery=0.7188, edit_dist=9.0000, sc_score=0.8324
#   ✓ Processed successfully
#
# [57/612] Processing file: 2ESI_1_A-B.fasta
#   Input sequence length: 44
#   Found 15 samples
#   Median metrics: perplexity=1.1888, recovery=0.7381, edit_dist=13.0000, sc_score=0.8725
#   ✓ Processed successfully
#
# [58/612] Processing file: 2ESJ_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1797, recovery=0.6429, edit_dist=15.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [59/612] Processing file: 2ET3_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2199, recovery=0.7619, edit_dist=10.0000, sc_score=0.8040
#   ✓ Processed successfully
#
# [60/612] Processing file: 2ET4_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1629, recovery=0.7857, edit_dist=9.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [61/612] Processing file: 2ET5_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1205, recovery=0.5952, edit_dist=17.0000, sc_score=0.9113
#   ✓ Processed successfully
#
# [62/612] Processing file: 2ET8_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1585, recovery=0.5000, edit_dist=19.0000, sc_score=0.8399
#   ✓ Processed successfully
#
# [63/612] Processing file: 2F4S_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2768, recovery=0.5833, edit_dist=16.5000, sc_score=0.8015
#   ✓ Processed successfully
#
# [64/612] Processing file: 2F4U_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.3120, recovery=0.4625, edit_dist=19.0000, sc_score=0.7310
#   ✓ Processed successfully
#
# [65/612] Processing file: 2G5K_1_A-B.fasta
#   Input sequence length: 44
#   Found 16 samples
#   Median metrics: perplexity=1.1892, recovery=0.6136, edit_dist=17.0000, sc_score=0.6019
#   ✓ Processed successfully
#
# [66/612] Processing file: 2O3X_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2391, recovery=0.6905, edit_dist=12.0000, sc_score=0.9059
#   ✓ Processed successfully
#
# [67/612] Processing file: 2OE5_1_B-A.fasta
#   Input sequence length: 33
#   Found 14 samples
#   Median metrics: perplexity=1.2214, recovery=0.5323, edit_dist=11.5000, sc_score=0.3872
#   ✓ Processed successfully
#
# [68/612] Processing file: 2OE6_1_B-A.fasta
#   Input sequence length: 33
#   Found 12 samples
#   Median metrics: perplexity=1.1339, recovery=0.3871, edit_dist=17.0000, sc_score=0.8401
#   ✓ Processed successfully
#
# [69/612] Processing file: 2OE8_1_B-A.fasta
#   Input sequence length: 33
#   Found 3 samples
#   Median metrics: perplexity=1.2351, recovery=0.4516, edit_dist=15.0000, sc_score=0.7957
#   ✓ Processed successfully
#
# [70/612] Processing file: 2OEU_1_A.fasta
#   Input sequence length: 42
#   Found 14 samples
#   Median metrics: perplexity=1.4285, recovery=0.4762, edit_dist=17.5000, sc_score=0.5680
#   ✓ Processed successfully
#
# [71/612] Processing file: 2PWT_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1816, recovery=0.6667, edit_dist=14.0000, sc_score=0.8157
#   ✓ Processed successfully
#
# [72/612] Processing file: 2R92_1_T-P.fasta
#   Input sequence length: 19
#   Found 16 samples
#   Median metrics: perplexity=1.2867, recovery=0.4412, edit_dist=9.0000, sc_score=0.8597
#   ✓ Processed successfully
#
# [73/612] Processing file: 2ZZM_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2313, recovery=0.5476, edit_dist=35.5000, sc_score=0.4662
#   ✓ Processed successfully
#
# [74/612] Processing file: 300D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [75/612] Processing file: 301D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [76/612] Processing file: 315D_1_A-B.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1248, recovery=0.3333, edit_dist=9.5000, sc_score=0.6916
#   ✓ Processed successfully
#
# [77/612] Processing file: 357D_1_C-B-A.fasta
#   Input sequence length: 60
#   Found 16 samples
#   Median metrics: perplexity=1.2236, recovery=0.5614, edit_dist=24.0000, sc_score=0.7426
#   ✓ Processed successfully
#
# [78/612] Processing file: 359D_1_B-A.fasta
#   Input sequence length: 41
#   Warning: No valid sample metrics found
#   ✗ Processing failed
#
# [79/612] Processing file: 364D_1_C-B-A.fasta
#   Input sequence length: 60
#   Found 16 samples
#   Median metrics: perplexity=1.2277, recovery=0.5603, edit_dist=25.0000, sc_score=0.8172
#   ✓ Processed successfully
#
# [80/612] Processing file: 379D_1_B-A.fasta
#   Input sequence length: 41
#   Found 3 samples
#   Median metrics: perplexity=1.4092, recovery=0.4211, edit_dist=20.0000, sc_score=0.1246
#   ✓ Processed successfully
#
# [81/612] Processing file: 3A3A_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1762, recovery=0.6511, edit_dist=28.5000, sc_score=0.6238
#   ✓ Processed successfully
#
# [82/612] Processing file: 3ADB_1_C.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.2487, recovery=0.4511, edit_dist=42.0000, sc_score=0.9563
#   ✓ Processed successfully
#
# [83/612] Processing file: 3ADB_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.2622, recovery=0.3913, edit_dist=45.0000, sc_score=0.9407
#   ✓ Processed successfully
#
# [84/612] Processing file: 3ADC_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.1981, recovery=0.4659, edit_dist=42.0000, sc_score=0.9558
#   ✓ Processed successfully
#
# [85/612] Processing file: 3ADC_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.2391, recovery=0.4239, edit_dist=43.0000, sc_score=0.9424
#   ✓ Processed successfully
#
# [86/612] Processing file: 3ADD_1_C.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2230, recovery=0.5114, edit_dist=38.5000, sc_score=0.9545
#   ✓ Processed successfully
#
# [87/612] Processing file: 3ADD_1_D.fasta
#   Input sequence length: 88
#   Found 16 samples
#   Median metrics: perplexity=1.2490, recovery=0.3921, edit_dist=41.0000, sc_score=0.9334
#   ✓ Processed successfully
#
# [88/612] Processing file: 3AM1_1_B.fasta
#   Input sequence length: 81
#   Found 16 samples
#   Median metrics: perplexity=1.1825, recovery=0.5494, edit_dist=36.0000, sc_score=0.9369
#   ✓ Processed successfully
#
# [89/612] Processing file: 3BSN_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.2075, recovery=0.3571, edit_dist=9.0000, sc_score=0.9079
#   ✓ Processed successfully
#
# [90/612] Processing file: 3BSO_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.2623, recovery=0.6250, edit_dist=5.0000, sc_score=0.9220
#   ✓ Processed successfully
#
# [91/612] Processing file: 3CUL_1_C.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.1681, recovery=0.6111, edit_dist=34.0000, sc_score=0.9107
#   ✓ Processed successfully
#
# [92/612] Processing file: 3CUL_1_D.fasta
#   Input sequence length: 92
#   Found 16 samples
#   Median metrics: perplexity=1.1854, recovery=0.6196, edit_dist=31.0000, sc_score=0.8916
#   ✓ Processed successfully
#
# [93/612] Processing file: 3CUN_1_C.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.2005, recovery=0.5275, edit_dist=39.0000, sc_score=0.9044
#   ✓ Processed successfully
#
# [94/612] Processing file: 3CUN_1_D.fasta
#   Input sequence length: 91
#   Found 16 samples
#   Median metrics: perplexity=1.2132, recovery=0.5824, edit_dist=36.0000, sc_score=0.8379
#   ✓ Processed successfully
#
# [95/612] Processing file: 3EGZ_1_B.fasta
#   Input sequence length: 65
#   Found 16 samples
#   Median metrics: perplexity=1.2418, recovery=0.5703, edit_dist=25.0000, sc_score=0.8496
#   ✓ Processed successfully
#
# [96/612] Processing file: 3H5X_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.2849, recovery=0.4375, edit_dist=8.0000, sc_score=0.9220
#   ✓ Processed successfully
#
# [97/612] Processing file: 3H5Y_1_T-P.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.3239, recovery=0.4375, edit_dist=8.0000, sc_score=0.9220
#   ✓ Processed successfully
#
# [98/612] Processing file: 3HL2_1_E.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.2025, recovery=0.5610, edit_dist=32.0000, sc_score=0.4558
#   ✓ Processed successfully
#
# [99/612] Processing file: 3J9M_1_AA.fasta
#   Input sequence length: 923
#   Found 16 samples
#   Median metrics: perplexity=1.4042, recovery=0.7161, edit_dist=249.0000, sc_score=0.4289
#   ✓ Processed successfully
#
# [100/612] Processing file: 3J9Y_1_v.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.1246, recovery=0.8561, edit_dist=10.5000, sc_score=0.4737
#   ✓ Processed successfully
#
# [101/612] Processing file: 3JB7_1_t-m.fasta
#   Input sequence length: 11
#   Found 16 samples
#   Median metrics: perplexity=1.4104, recovery=0.2727, edit_dist=8.0000, sc_score=0.7610
#   ✓ Processed successfully
#
# [102/612] Processing file: 3JCJ_1_v.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.2467, recovery=0.6301, edit_dist=25.5000, sc_score=0.4877
#   ✓ Processed successfully
#
# [103/612] Processing file: 3JCN_1_v.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.2569, recovery=0.6301, edit_dist=25.5000, sc_score=0.4877
#   ✓ Processed successfully
#
# [104/612] Processing file: 3JCS_1_3.fasta
#   Input sequence length: 184
#   Found 16 samples
#   Median metrics: perplexity=1.4566, recovery=0.3424, edit_dist=103.0000, sc_score=0.5452
#   ✓ Processed successfully
#
# [105/612] Processing file: 3LRR_1_C-D.fasta
#   Input sequence length: 22
#   Found 8 samples
#   Median metrics: perplexity=1.2249, recovery=0.0455, edit_dist=17.0000, sc_score=0.7745
#   ✓ Processed successfully
#
# [106/612] Processing file: 3MQK_1_D-E.fasta
#   Input sequence length: 22
#   Found 16 samples
#   Median metrics: perplexity=1.2683, recovery=0.1364, edit_dist=15.0000, sc_score=0.6067
#   ✓ Processed successfully
#
# [107/612] Processing file: 3NCU_1_C-D.fasta
#   Input sequence length: 22
#   Found 16 samples
#   Median metrics: perplexity=1.1140, recovery=0.0455, edit_dist=11.0000, sc_score=0.9466
#   ✓ Processed successfully
#
# [108/612] Processing file: 3OG8_1_C-D.fasta
#   Input sequence length: 28
#   Found 16 samples
#   Median metrics: perplexity=1.1086, recovery=0.3462, edit_dist=13.0000, sc_score=0.9560
#   ✓ Processed successfully
#
# [109/612] Processing file: 3OL6_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 13 samples
#   Median metrics: perplexity=1.3288, recovery=0.3030, edit_dist=39.0000, sc_score=0.8295
#   ✓ Processed successfully
#
# [110/612] Processing file: 3OL6_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 16 samples
#   Median metrics: perplexity=1.2724, recovery=0.3357, edit_dist=42.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [111/612] Processing file: 3OL7_1_B-F-C-G-D-H.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.2679, recovery=0.3529, edit_dist=36.5000, sc_score=0.8576
#   ✓ Processed successfully
#
# [112/612] Processing file: 3OL7_1_J-N-K-O-L-P.fasta
#   Input sequence length: 70
#   Found 15 samples
#   Median metrics: perplexity=1.2254, recovery=0.3824, edit_dist=36.0000, sc_score=0.8882
#   ✓ Processed successfully
#
# [113/612] Processing file: 3OL8_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 16 samples
#   Median metrics: perplexity=1.2849, recovery=0.4470, edit_dist=34.0000, sc_score=0.8881
#   ✓ Processed successfully
#
# [114/612] Processing file: 3OL8_1_J-N-K-O-L-P.fasta
#   Input sequence length: 72
#   Found 15 samples
#   Median metrics: perplexity=1.2286, recovery=0.3824, edit_dist=36.0000, sc_score=0.8554
#   ✓ Processed successfully
#
# [115/612] Processing file: 3OL9_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 16 samples
#   Median metrics: perplexity=1.2700, recovery=0.3333, edit_dist=39.0000, sc_score=0.9060
#   ✓ Processed successfully
#
# [116/612] Processing file: 3OL9_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 15 samples
#   Median metrics: perplexity=1.2741, recovery=0.2857, edit_dist=44.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [117/612] Processing file: 3OLB_1_B-F-C-G-D-H.fasta
#   Input sequence length: 70
#   Found 16 samples
#   Median metrics: perplexity=1.3281, recovery=0.3485, edit_dist=37.0000, sc_score=0.9060
#   ✓ Processed successfully
#
# [118/612] Processing file: 3OLB_1_J-N-K-O-L-P.fasta
#   Input sequence length: 74
#   Found 14 samples
#   Median metrics: perplexity=1.2740, recovery=0.3000, edit_dist=43.0000, sc_score=0.9657
#   ✓ Processed successfully
#
# [119/612] Processing file: 3OWI_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1908, recovery=0.6337, edit_dist=30.0000, sc_score=0.5407
#   ✓ Processed successfully
#
# [120/612] Processing file: 3OWI_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2419, recovery=0.5805, edit_dist=33.0000, sc_score=0.6889
#   ✓ Processed successfully
#
# [121/612] Processing file: 3OWW_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1848, recovery=0.6395, edit_dist=30.0000, sc_score=0.4939
#   ✓ Processed successfully
#
# [122/612] Processing file: 3OWW_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2411, recovery=0.5756, edit_dist=32.0000, sc_score=0.7992
#   ✓ Processed successfully
#
# [123/612] Processing file: 3OWZ_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2382, recovery=0.5698, edit_dist=35.5000, sc_score=0.8131
#   ✓ Processed successfully
#
# [124/612] Processing file: 3OWZ_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.1850, recovery=0.5915, edit_dist=32.5000, sc_score=0.6202
#   ✓ Processed successfully
#
# [125/612] Processing file: 3OX0_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1425, recovery=0.5698, edit_dist=34.0000, sc_score=0.6704
#   ✓ Processed successfully
#
# [126/612] Processing file: 3OX0_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2342, recovery=0.5919, edit_dist=32.5000, sc_score=0.7853
#   ✓ Processed successfully
#
# [127/612] Processing file: 3OXB_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2201, recovery=0.6047, edit_dist=32.5000, sc_score=0.7572
#   ✓ Processed successfully
#
# [128/612] Processing file: 3OXB_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1883, recovery=0.5698, edit_dist=31.0000, sc_score=0.6665
#   ✓ Processed successfully
#
# [129/612] Processing file: 3OXD_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1848, recovery=0.6395, edit_dist=29.0000, sc_score=0.7838
#   ✓ Processed successfully
#
# [130/612] Processing file: 3OXD_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2102, recovery=0.5465, edit_dist=34.0000, sc_score=0.7780
#   ✓ Processed successfully
#
# [131/612] Processing file: 3OXE_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1896, recovery=0.6279, edit_dist=30.5000, sc_score=0.8002
#   ✓ Processed successfully
#
# [132/612] Processing file: 3OXE_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2581, recovery=0.5459, edit_dist=32.5000, sc_score=0.7994
#   ✓ Processed successfully
#
# [133/612] Processing file: 3OXJ_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1982, recovery=0.5988, edit_dist=31.0000, sc_score=0.7934
#   ✓ Processed successfully
#
# [134/612] Processing file: 3OXJ_1_B.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.2002, recovery=0.5706, edit_dist=32.0000, sc_score=0.4891
#   ✓ Processed successfully
#
# [135/612] Processing file: 3OXM_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.2355, recovery=0.6047, edit_dist=32.5000, sc_score=0.7736
#   ✓ Processed successfully
#
# [136/612] Processing file: 3OXM_1_B.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2269, recovery=0.5517, edit_dist=33.0000, sc_score=0.8132
#   ✓ Processed successfully
#
# [137/612] Processing file: 3Q1Q_1_C.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1321, recovery=0.6829, edit_dist=29.0000, sc_score=0.8352
#   ✓ Processed successfully
#
# [138/612] Processing file: 3Q1R_1_C.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1532, recovery=0.7073, edit_dist=27.0000, sc_score=0.8352
#   ✓ Processed successfully
#
# [139/612] Processing file: 3RG5_1_A.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1770, recovery=0.5814, edit_dist=34.0000, sc_score=0.7616
#   ✓ Processed successfully
#
# [140/612] Processing file: 3RG5_1_B.fasta
#   Input sequence length: 86
#   Found 16 samples
#   Median metrics: perplexity=1.1303, recovery=0.5988, edit_dist=33.0000, sc_score=0.7829
#   ✓ Processed successfully
#
# [141/612] Processing file: 3S4P_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1081, recovery=0.6190, edit_dist=16.0000, sc_score=0.8157
#   ✓ Processed successfully
#
# [142/612] Processing file: 3TD0_1_B-A.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1555, recovery=0.6585, edit_dist=14.0000, sc_score=0.5143
#   ✓ Processed successfully
#
# [143/612] Processing file: 3TD1_1_B-A.fasta
#   Input sequence length: 43
#   Found 2 samples
#   Median metrics: perplexity=1.2606, recovery=0.5834, edit_dist=16.5000, sc_score=0.1293
#   ✓ Processed successfully
#
# [144/612] Processing file: 3TRZ_1_U.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1992, recovery=0.3000, edit_dist=14.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [145/612] Processing file: 3TRZ_1_V.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.2276, recovery=0.4750, edit_dist=10.5000, sc_score=0.8921
#   ✓ Processed successfully
#
# [146/612] Processing file: 3TRZ_1_W.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1919, recovery=0.4000, edit_dist=12.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [147/612] Processing file: 3TRZ_1_X.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.2072, recovery=0.5000, edit_dist=10.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [148/612] Processing file: 3TRZ_1_Y.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.2050, recovery=0.5000, edit_dist=10.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [149/612] Processing file: 3TRZ_1_Z.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1954, recovery=0.4000, edit_dist=12.0000, sc_score=0.8921
#   ✓ Processed successfully
#
# [150/612] Processing file: 3W3S_1_B.fasta
#   Input sequence length: 98
#   Found 16 samples
#   Median metrics: perplexity=1.1953, recovery=0.5969, edit_dist=36.5000, sc_score=0.8420
#   ✓ Processed successfully
#
# [151/612] Processing file: 3WRU_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1472, recovery=0.6786, edit_dist=13.5000, sc_score=0.8157
#   ✓ Processed successfully
#
# [152/612] Processing file: 3ZJV_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.1773, recovery=0.6548, edit_dist=27.5000, sc_score=0.5305
#   ✓ Processed successfully
#
# [153/612] Processing file: 462D_1_B-A.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2870, recovery=0.3409, edit_dist=27.0000, sc_score=0.9205
#   ✓ Processed successfully
#
# [154/612] Processing file: 488D_1_D-B-A-C.fasta
#   Input sequence length: 65
#   Found 4 samples
#   Median metrics: perplexity=1.3196, recovery=0.3443, edit_dist=33.5000, sc_score=0.0859
#   ✓ Processed successfully
#
# [155/612] Processing file: 4AS1_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.1521, recovery=0.7561, edit_dist=20.0000, sc_score=0.4347
#   ✓ Processed successfully
#
# [156/612] Processing file: 4CQN_1_B.fasta
#   Input sequence length: 82
#   Found 16 samples
#   Median metrics: perplexity=1.1488, recovery=0.6829, edit_dist=24.5000, sc_score=0.6278
#   ✓ Processed successfully
#
# [157/612] Processing file: 4F8V_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1256, recovery=0.7143, edit_dist=12.0000, sc_score=0.7252
#   ✓ Processed successfully
#
# [158/612] Processing file: 4GKJ_1_X-W.fasta
#   Input sequence length: 11
#   Found 16 samples
#   Median metrics: perplexity=1.4135, recovery=0.3000, edit_dist=7.0000, sc_score=0.6857
#   ✓ Processed successfully
#
# [159/612] Processing file: 4GPW_1_A-B.fasta
#   Input sequence length: 44
#   Found 16 samples
#   Median metrics: perplexity=1.1488, recovery=0.5909, edit_dist=17.0000, sc_score=0.7520
#   ✓ Processed successfully
#
# [160/612] Processing file: 4ILM_1_C.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1249, recovery=0.3333, edit_dist=7.0000, sc_score=0.5721
#   ✓ Processed successfully
#
# [161/612] Processing file: 4ILM_1_E.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1162, recovery=0.2667, edit_dist=8.0000, sc_score=0.8128
#   ✓ Processed successfully
#
# [162/612] Processing file: 4ILM_1_G.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1353, recovery=0.2000, edit_dist=9.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [163/612] Processing file: 4ILM_1_I.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1472, recovery=0.2667, edit_dist=8.0000, sc_score=0.8128
#   ✓ Processed successfully
#
# [164/612] Processing file: 4ILM_1_K.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1328, recovery=0.2000, edit_dist=9.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [165/612] Processing file: 4ILM_1_M.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1042, recovery=0.3333, edit_dist=8.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [166/612] Processing file: 4ILM_1_O.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1596, recovery=0.2667, edit_dist=7.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [167/612] Processing file: 4ILM_1_R.fasta
#   Input sequence length: 16
#   Found 16 samples
#   Median metrics: perplexity=1.1286, recovery=0.5333, edit_dist=7.0000, sc_score=0.3917
#   ✓ Processed successfully
#
# [168/612] Processing file: 4K32_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.2001, recovery=0.7143, edit_dist=11.0000, sc_score=0.9059
#   ✓ Processed successfully
#
# [169/612] Processing file: 4K4S_1_B-F-C-G-D-H.fasta
#   Input sequence length: 67
#   Found 16 samples
#   Median metrics: perplexity=1.3142, recovery=0.4615, edit_dist=35.0000, sc_score=0.9442
#   ✓ Processed successfully
#
# [170/612] Processing file: 4MCF_1_B-D-C-A.fasta
#   Input sequence length: 39
#   Found 16 samples
#   Median metrics: perplexity=1.2304, recovery=0.4722, edit_dist=20.0000, sc_score=0.9379
#   ✓ Processed successfully
#
# [171/612] Processing file: 4MGM_1_A.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.1426, recovery=0.6667, edit_dist=21.0000, sc_score=0.5827
#   ✓ Processed successfully
#
# [172/612] Processing file: 4MGM_1_B.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.1699, recovery=0.6667, edit_dist=21.0000, sc_score=0.8515
#   ✓ Processed successfully
#
# [173/612] Processing file: 4MSB_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1847, recovery=0.2778, edit_dist=10.0000, sc_score=0.8605
#   ✓ Processed successfully
#
# [174/612] Processing file: 4MSB_1_C-D.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1282, recovery=0.2778, edit_dist=11.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [175/612] Processing file: 4MSB_1_E-F.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1623, recovery=0.3333, edit_dist=13.0000, sc_score=0.4905
#   ✓ Processed successfully
#
# [176/612] Processing file: 4MSR_1_A-B.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1979, recovery=0.3333, edit_dist=10.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [177/612] Processing file: 4O41_1_B-A.fasta
#   Input sequence length: 21
#   Found 13 samples
#   Median metrics: perplexity=1.1175, recovery=0.6000, edit_dist=9.0000, sc_score=0.8615
#   ✓ Processed successfully
#
# [178/612] Processing file: 4O41_1_C-D.fasta
#   Input sequence length: 20
#   Found 13 samples
#   Median metrics: perplexity=1.1361, recovery=0.5500, edit_dist=7.0000, sc_score=0.6688
#   ✓ Processed successfully
#
# [179/612] Processing file: 4P20_1_A-B.fasta
#   Input sequence length: 42
#   Found 16 samples
#   Median metrics: perplexity=1.1581, recovery=0.6667, edit_dist=14.0000, sc_score=0.8484
#   ✓ Processed successfully
#
# [180/612] Processing file: 4P3S_1_B-A.fasta
#   Input sequence length: 41
#   Found 13 samples
#   Median metrics: perplexity=1.2013, recovery=0.4634, edit_dist=18.0000, sc_score=0.5654
#   ✓ Processed successfully
#
# [181/612] Processing file: 4PJO_1_1.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.2209, recovery=0.5212, edit_dist=22.0000, sc_score=0.9254
#   ✓ Processed successfully
#
# [182/612] Processing file: 4PJO_1_2.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.2315, recovery=0.5106, edit_dist=21.0000, sc_score=0.9254
#   ✓ Processed successfully
#
# [183/612] Processing file: 4PJO_1_3.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2556, recovery=0.5217, edit_dist=21.0000, sc_score=0.9254
#   ✓ Processed successfully
#
# [184/612] Processing file: 4PJO_1_4.fasta
#   Input sequence length: 48
#   Found 16 samples
#   Median metrics: perplexity=1.3235, recovery=0.4688, edit_dist=24.5000, sc_score=0.9254
#   ✓ Processed successfully
#
# [185/612] Processing file: 4PMI_1_A.fasta
#   Input sequence length: 40
#   Found 15 samples
#   Median metrics: perplexity=1.1793, recovery=0.4872, edit_dist=18.0000, sc_score=0.7838
#   ✓ Processed successfully
#
# [186/612] Processing file: 4QJD_1_B.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2633, recovery=0.5000, edit_dist=21.5000, sc_score=0.6744
#   ✓ Processed successfully
#
# [187/612] Processing file: 4QJD_1_D.fasta
#   Input sequence length: 46
#   Found 1 samples
#   Median metrics: perplexity=1.2695, recovery=0.3913, edit_dist=23.0000, sc_score=0.5280
#   ✓ Processed successfully
#
# [188/612] Processing file: 4QJD_1_F.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.2407, recovery=0.3913, edit_dist=24.0000, sc_score=0.8548
#   ✓ Processed successfully
#
# [189/612] Processing file: 4QJD_1_H.fasta
#   Input sequence length: 46
#   Found 16 samples
#   Median metrics: perplexity=1.3019, recovery=0.4783, edit_dist=23.0000, sc_score=0.5939
#   ✓ Processed successfully
#
# [190/612] Processing file: 4QJH_1_B.fasta
#   Input sequence length: 47
#   Found 15 samples
#   Median metrics: perplexity=1.3777, recovery=0.3404, edit_dist=25.0000, sc_score=0.7058
#   ✓ Processed successfully
#
# [191/612] Processing file: 4QJH_1_D.fasta
#   Input sequence length: 47
#   Found 8 samples
#   Median metrics: perplexity=1.4539, recovery=0.3617, edit_dist=24.5000, sc_score=0.7017
#   ✓ Processed successfully
#
# [192/612] Processing file: 4QJH_1_F.fasta
#   Input sequence length: 47
#   Found 11 samples
#   Median metrics: perplexity=1.4945, recovery=0.3830, edit_dist=24.0000, sc_score=0.7991
#   ✓ Processed successfully
#
# [193/612] Processing file: 4QPX_1_P-T.fasta
#   Input sequence length: 15
#   Found 16 samples
#   Median metrics: perplexity=1.1200, recovery=0.0000, edit_dist=9.0000, sc_score=0.8063
#   ✓ Processed successfully
#
# [194/612] Processing file: 4QYZ_1_L.fasta
#   Input sequence length: 55
#   Found 7 samples
#   Median metrics: perplexity=1.5511, recovery=0.2778, edit_dist=37.0000, sc_score=0.2869
#   ✓ Processed successfully
#
# [195/612] Processing file: 4RQE_1_B.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2033, recovery=0.5595, edit_dist=35.0000, sc_score=0.5944
#   ✓ Processed successfully
#
# [196/612] Processing file: 4RQE_1_D.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.2597, recovery=0.5121, edit_dist=34.5000, sc_score=0.6485
#   ✓ Processed successfully
#
# [197/612] Processing file: 4TNA_1_A.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.1934, recovery=0.6774, edit_dist=19.0000, sc_score=0.3725
#   ✓ Processed successfully
#
# [198/612] Processing file: 4TRA_1_A.fasta
#   Input sequence length: 62
#   Found 12 samples
#   Median metrics: perplexity=1.1864, recovery=0.7016, edit_dist=18.0000, sc_score=0.3910
#   ✓ Processed successfully
#
# [199/612] Processing file: 4TVX_1_L.fasta
#   Input sequence length: 60
#   Found 12 samples
#   Median metrics: perplexity=1.6288, recovery=0.2373, edit_dist=43.0000, sc_score=0.3149
#   ✓ Processed successfully
#
# [200/612] Processing file: 4TVX_1_X.fasta
#   Input sequence length: 59
#   Found 11 samples
#   Median metrics: perplexity=1.4627, recovery=0.2632, edit_dist=42.0000, sc_score=0.2871
#   ✓ Processed successfully
#
# [201/612] Processing file: 4U7U_1_L.fasta
#   Input sequence length: 61
#   Found 10 samples
#   Median metrics: perplexity=1.7641, recovery=0.3500, edit_dist=37.5000, sc_score=0.5116
#   ✓ Processed successfully
#
# [202/612] Processing file: 4U7U_1_X.fasta
#   Input sequence length: 61
#   Found 13 samples
#   Median metrics: perplexity=1.8792, recovery=0.3333, edit_dist=38.0000, sc_score=0.6378
#   ✓ Processed successfully
#
# [203/612] Processing file: 4V42_1_AB.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2086, recovery=0.7339, edit_dist=15.0000, sc_score=0.4859
#   ✓ Processed successfully
#
# [204/612] Processing file: 4V42_1_AC.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2242, recovery=0.6774, edit_dist=19.0000, sc_score=0.3698
#   ✓ Processed successfully
#
# [205/612] Processing file: 4V87_1_BB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2822, recovery=0.5517, edit_dist=37.0000, sc_score=0.5337
#   ✓ Processed successfully
#
# [206/612] Processing file: 4V87_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2504, recovery=0.5344, edit_dist=39.0000, sc_score=0.5553
#   ✓ Processed successfully
#
# [207/612] Processing file: 4V8B_1_AB.fasta
#   Input sequence length: 87
#   Found 14 samples
#   Median metrics: perplexity=1.2196, recovery=0.5919, edit_dist=35.5000, sc_score=0.2247
#   ✓ Processed successfully
#
# [208/612] Processing file: 4V8B_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2392, recovery=0.5230, edit_dist=40.0000, sc_score=0.4824
#   ✓ Processed successfully
#
# [209/612] Processing file: 4V8C_1_CB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2326, recovery=0.5287, edit_dist=40.0000, sc_score=0.4231
#   ✓ Processed successfully
#
# [210/612] Processing file: 4V8C_1_DB.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2340, recovery=0.5230, edit_dist=40.0000, sc_score=0.4920
#   ✓ Processed successfully
#
# [211/612] Processing file: 4V8D_1_AB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2492, recovery=0.5535, edit_dist=37.0000, sc_score=0.5587
#   ✓ Processed successfully
#
# [212/612] Processing file: 4V8D_1_AD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2826, recovery=0.6071, edit_dist=32.0000, sc_score=0.6659
#   ✓ Processed successfully
#
# [213/612] Processing file: 4V8D_1_CB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2341, recovery=0.5595, edit_dist=33.5000, sc_score=0.4965
#   ✓ Processed successfully
#
# [214/612] Processing file: 4V8D_1_CD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2361, recovery=0.6072, edit_dist=33.0000, sc_score=0.5019
#   ✓ Processed successfully
#
# [215/612] Processing file: 4V8E_1_BB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3175, recovery=0.5893, edit_dist=34.5000, sc_score=0.5525
#   ✓ Processed successfully
#
# [216/612] Processing file: 4V8E_1_BD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2666, recovery=0.5595, edit_dist=33.0000, sc_score=0.6929
#   ✓ Processed successfully
#
# [217/612] Processing file: 4V8E_1_DB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2978, recovery=0.5893, edit_dist=34.0000, sc_score=0.5976
#   ✓ Processed successfully
#
# [218/612] Processing file: 4V8E_1_DD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2706, recovery=0.5595, edit_dist=34.0000, sc_score=0.6852
#   ✓ Processed successfully
#
# [219/612] Processing file: 4V8F_1_BB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2768, recovery=0.6548, edit_dist=29.0000, sc_score=0.6646
#   ✓ Processed successfully
#
# [220/612] Processing file: 4V8F_1_BD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.3203, recovery=0.6190, edit_dist=30.5000, sc_score=0.6392
#   ✓ Processed successfully
#
# [221/612] Processing file: 4V8F_1_CB.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2496, recovery=0.5952, edit_dist=32.0000, sc_score=0.5248
#   ✓ Processed successfully
#
# [222/612] Processing file: 4V8F_1_CD.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2802, recovery=0.5952, edit_dist=32.0000, sc_score=0.5149
#   ✓ Processed successfully
#
# [223/612] Processing file: 4W5O_1_B-D.fasta
#   Input sequence length: 30
#   Found 16 samples
#   Median metrics: perplexity=1.3402, recovery=0.3704, edit_dist=17.0000, sc_score=0.9341
#   ✓ Processed successfully
#
# [224/612] Processing file: 4W5Q_1_B-D.fasta
#   Input sequence length: 28
#   Found 16 samples
#   Median metrics: perplexity=1.3465, recovery=0.4615, edit_dist=12.5000, sc_score=0.9340
#   ✓ Processed successfully
#
# [225/612] Processing file: 4W5T_1_B-D.fasta
#   Input sequence length: 26
#   Found 16 samples
#   Median metrics: perplexity=1.4320, recovery=0.4583, edit_dist=13.5000, sc_score=0.8629
#   ✓ Processed successfully
#
# [226/612] Processing file: 4WR6_1_1L.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.3067, recovery=0.5823, edit_dist=34.0000, sc_score=0.2510
#   ✓ Processed successfully
#
# [227/612] Processing file: 4WR6_1_3L.fasta
#   Input sequence length: 85
#   Found 16 samples
#   Median metrics: perplexity=1.3198, recovery=0.5176, edit_dist=40.0000, sc_score=0.3222
#   ✓ Processed successfully
#
# [228/612] Processing file: 4WRA_1_1L.fasta
#   Input sequence length: 84
#   Found 15 samples
#   Median metrics: perplexity=1.2842, recovery=0.6071, edit_dist=32.0000, sc_score=0.4970
#   ✓ Processed successfully
#
# [229/612] Processing file: 4WRA_1_3K.fasta
#   Input sequence length: 84
#   Found 16 samples
#   Median metrics: perplexity=1.2946, recovery=0.5714, edit_dist=33.0000, sc_score=0.6258
#   ✓ Processed successfully
#
# [230/612] Processing file: 4WRA_1_3L.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.2381, recovery=0.5181, edit_dist=37.0000, sc_score=0.2611
#   ✓ Processed successfully
#
# [231/612] Processing file: 4WSM_1_1K.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.2900, recovery=0.5482, edit_dist=34.5000, sc_score=0.3216
#   ✓ Processed successfully
#
# [232/612] Processing file: 4WSM_1_1L.fasta
#   Input sequence length: 83
#   Found 16 samples
#   Median metrics: perplexity=1.2589, recovery=0.5422, edit_dist=35.0000, sc_score=0.4666
#   ✓ Processed successfully
#
# [233/612] Processing file: 4X4N_1_G.fasta
#   Input sequence length: 20
#   Found 16 samples
#   Median metrics: perplexity=1.1378, recovery=0.1000, edit_dist=10.0000, sc_score=0.6149
#   ✓ Processed successfully
#
# [234/612] Processing file: 4X4U_1_G.fasta
#   Input sequence length: 18
#   Found 16 samples
#   Median metrics: perplexity=1.0840, recovery=0.4706, edit_dist=9.0000, sc_score=0.9320
#   ✓ Processed successfully
#
# [235/612] Processing file: 4Z4C_1_B-D.fasta
# ...
#   Input sequence length: 58
#   Found 16 samples
#   Median metrics: perplexity=1.4055, recovery=0.2931, edit_dist=33.0000, sc_score=0.5187
#   ✓ Processed successfully
#
# [540/612] Processing file: 7XJG_1_H.fasta
#   Input sequence length: 58
#   Found 14 samples
#   Median metrics: perplexity=1.4139, recovery=0.3707, edit_dist=29.5000, sc_score=0.5601
#   ✓ Processed successfully
#
# [541/612] Processing file: 7Y7P_1_E-J.fasta
#   Input sequence length: 17
#   Found 8 samples
#   Median metrics: perplexity=1.1859, recovery=0.1875, edit_dist=10.0000, sc_score=0.8099
#   ✓ Processed successfully
#
# [542/612] Processing file: 7Y7Q_1_C-D.fasta
#   Input sequence length: 17
#   Found 16 samples
#   Median metrics: perplexity=1.2039, recovery=0.1875, edit_dist=8.0000, sc_score=0.9092
#   ✓ Processed successfully
#
# [543/612] Processing file: 7Y82_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.6272, recovery=0.4394, edit_dist=32.0000, sc_score=0.9091
#   ✓ Processed successfully
#
# [544/612] Processing file: 7Y9Y_1_R-D.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.5316, recovery=0.4333, edit_dist=31.0000, sc_score=0.8730
#   ✓ Processed successfully
#
# [545/612] Processing file: 7YNA_1_B-C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.5785, recovery=0.3651, edit_dist=35.0000, sc_score=0.9131
#   ✓ Processed successfully
#
# [546/612] Processing file: 7YNB_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.5842, recovery=0.3939, edit_dist=36.0000, sc_score=0.9091
#   ✓ Processed successfully
#
# [547/612] Processing file: 7YNC_1_B-C.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.6462, recovery=0.3788, edit_dist=36.0000, sc_score=0.8920
#   ✓ Processed successfully
#
# [548/612] Processing file: 7YOJ_1_B.fasta
#   Input sequence length: 174
#   Found 16 samples
#   Median metrics: perplexity=1.5559, recovery=0.4080, edit_dist=87.0000, sc_score=0.6110
#   ✓ Processed successfully
#
# [549/612] Processing file: 7YR6_1_A.fasta
#   Input sequence length: 118
#   Found 16 samples
#   Median metrics: perplexity=1.3773, recovery=0.4322, edit_dist=62.0000, sc_score=0.7350
#   ✓ Processed successfully
#
# [550/612] Processing file: 7YR7_1_A.fasta
#   Input sequence length: 118
#   Found 16 samples
#   Median metrics: perplexity=1.3407, recovery=0.3898, edit_dist=65.0000, sc_score=0.6468
#   ✓ Processed successfully
#
# [551/612] Processing file: 7YYM_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.2416, recovery=0.4905, edit_dist=26.5000, sc_score=0.9044
#   ✓ Processed successfully
#
# [552/612] Processing file: 7YYN_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.2481, recovery=0.3636, edit_dist=28.5000, sc_score=0.8164
#   ✓ Processed successfully
#
# [553/612] Processing file: 7ZJW_1_F.fasta
#   Input sequence length: 90
#   Found 16 samples
#   Median metrics: perplexity=1.2281, recovery=0.4278, edit_dist=41.0000, sc_score=0.6208
#   ✓ Processed successfully
#
# [554/612] Processing file: 7ZPI_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.2434, recovery=0.3091, edit_dist=30.0000, sc_score=0.8465
#   ✓ Processed successfully
#
# [555/612] Processing file: 7ZPJ_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.2791, recovery=0.4727, edit_dist=27.5000, sc_score=0.8832
#   ✓ Processed successfully
#
# [556/612] Processing file: 7ZPK_1_B.fasta
#   Input sequence length: 55
#   Found 16 samples
#   Median metrics: perplexity=1.3062, recovery=0.4818, edit_dist=26.0000, sc_score=0.8292
#   ✓ Processed successfully
#
# [557/612] Processing file: 8A3L_1_V.fasta
#   Input sequence length: 73
#   Found 16 samples
#   Median metrics: perplexity=1.1294, recovery=0.7671, edit_dist=17.0000, sc_score=0.4852
#   ✓ Processed successfully
#
# [558/612] Processing file: 8ANY_1_AA.fasta
#   Input sequence length: 949
#   Found 16 samples
#   Median metrics: perplexity=1.3293, recovery=0.8182, edit_dist=165.5000, sc_score=0.3831
#   ✓ Processed successfully
#
# [559/612] Processing file: 8AS7_1_P-T-G.fasta
#   Input sequence length: 37
#   Found 15 samples
#   Median metrics: perplexity=1.3641, recovery=0.3889, edit_dist=18.0000, sc_score=0.5925
#   ✓ Processed successfully
#
# [560/612] Processing file: 8ASB_1_P-T-G.fasta
#   Input sequence length: 38
#   Found 16 samples
#   Median metrics: perplexity=1.3830, recovery=0.4460, edit_dist=19.0000, sc_score=0.5266
#   ✓ Processed successfully
#
# [561/612] Processing file: 8C6J_1_2-6.fasta
#   Input sequence length: 239
#   Found 16 samples
#   Median metrics: perplexity=1.5034, recovery=0.5272, edit_dist=99.5000, sc_score=0.3889
#   ✓ Processed successfully
#
# [562/612] Processing file: 8CA7_1_A.fasta
#   Input sequence length: 498
#   Found 16 samples
#   Median metrics: perplexity=1.0966, recovery=0.9598, edit_dist=18.5000, sc_score=0.3731
#   ✓ Processed successfully
#
# [563/612] Processing file: 8CAS_1_1.fasta
#   Input sequence length: 64
#   Found 16 samples
#   Median metrics: perplexity=1.2626, recovery=0.4844, edit_dist=30.0000, sc_score=0.8609
#   ✓ Processed successfully
#
# [564/612] Processing file: 8CAZ_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0690, recovery=0.9803, edit_dist=9.0000, sc_score=0.4993
#   ✓ Processed successfully
#
# [565/612] Processing file: 8CF1_1_A.fasta
#   Input sequence length: 481
#   Found 16 samples
#   Median metrics: perplexity=1.0661, recovery=0.9854, edit_dist=7.0000, sc_score=0.4838
#   ✓ Processed successfully
#
# [566/612] Processing file: 8CF8_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0661, recovery=0.9869, edit_dist=6.0000, sc_score=0.4670
#   ✓ Processed successfully
#
# [567/612] Processing file: 8CGI_1_A.fasta
#   Input sequence length: 457
#   Found 16 samples
#   Median metrics: perplexity=1.0615, recovery=0.9869, edit_dist=6.0000, sc_score=0.4913
#   ✓ Processed successfully
#
# [568/612] Processing file: 8CSP_1_A.fasta
#   Input sequence length: 737
#   Found 16 samples
#   Median metrics: perplexity=1.3958, recovery=0.5875, edit_dist=276.5000, sc_score=0.4910
#   ✓ Processed successfully
#
# [569/612] Processing file: 8CSQ_1_A.fasta
#   Input sequence length: 802
#   Found 16 samples
#   Median metrics: perplexity=1.3792, recovery=0.6066, edit_dist=286.5000, sc_score=0.4628
#   ✓ Processed successfully
#
# [570/612] Processing file: 8CSR_1_A.fasta
#   Input sequence length: 853
#   Found 16 samples
#   Median metrics: perplexity=1.3759, recovery=0.6395, edit_dist=284.5000, sc_score=0.4703
#   ✓ Processed successfully
#
# [571/612] Processing file: 8CSS_1_A.fasta
#   Input sequence length: 844
#   Found 16 samples
#   Median metrics: perplexity=1.3560, recovery=0.6665, edit_dist=263.5000, sc_score=0.4599
#   ✓ Processed successfully
#
# [572/612] Processing file: 8CST_1_A.fasta
#   Input sequence length: 886
#   Found 16 samples
#   Median metrics: perplexity=1.3495, recovery=0.6664, edit_dist=271.0000, sc_score=0.4641
#   ✓ Processed successfully
#
# [573/612] Processing file: 8CSU_1_A.fasta
#   Input sequence length: 881
#   Found 16 samples
#   Median metrics: perplexity=1.3454, recovery=0.6447, edit_dist=292.5000, sc_score=0.4382
#   ✓ Processed successfully
#
# [574/612] Processing file: 8CVO_1_A.fasta
#   Input sequence length: 469
#   Found 16 samples
#   Median metrics: perplexity=1.1685, recovery=0.8529, edit_dist=66.5000, sc_score=0.3218
#   ✓ Processed successfully
#
# [575/612] Processing file: 8E0F_1_D-C.fasta
#   Input sequence length: 63
#   Found 16 samples
#   Median metrics: perplexity=1.1885, recovery=0.4262, edit_dist=31.0000, sc_score=0.9817
#   ✓ Processed successfully
#
# [576/612] Processing file: 8E40_1_r-R.fasta
#   Input sequence length: 47
#   Found 16 samples
#   Median metrics: perplexity=1.2373, recovery=0.2766, edit_dist=34.0000, sc_score=0.8629
#   ✓ Processed successfully
#
# [577/612] Processing file: 8E4X_1_C-D.fasta
#   Input sequence length: 62
#   Found 16 samples
#   Median metrics: perplexity=1.2342, recovery=0.3000, edit_dist=30.5000, sc_score=0.9543
#   ✓ Processed successfully
#
# [578/612] Processing file: 8E5T_1_1-2.fasta
#   Input sequence length: 881
#   Found 16 samples
#   Median metrics: perplexity=1.2319, recovery=0.7293, edit_dist=218.5000, sc_score=0.6319
#   ✓ Processed successfully
#
# [579/612] Processing file: 8EEY_1_C-D.fasta
#   Input sequence length: 66
#   Found 16 samples
#   Median metrics: perplexity=1.6595, recovery=0.4766, edit_dist=31.0000, sc_score=0.8485
#   ✓ Processed successfully
#
# [580/612] Processing file: 8FJK_1_a1-b1.fasta
#   Input sequence length: 104
#   Found 16 samples
#   Median metrics: perplexity=1.2645, recovery=0.3922, edit_dist=54.0000, sc_score=0.9899
#   ✓ Processed successfully
#
# [581/612] Processing file: 8FJK_1_a2-b2.fasta
#   Input sequence length: 120
#   Found 16 samples
#   Median metrics: perplexity=1.2766, recovery=0.3898, edit_dist=57.5000, sc_score=0.9913
#   ✓ Processed successfully
#
# [582/612] Processing file: 8FJK_1_a3-b3.fasta
#   Input sequence length: 80
#   Found 16 samples
#   Median metrics: perplexity=1.2521, recovery=0.4872, edit_dist=35.0000, sc_score=0.9866
#   ✓ Processed successfully
#
# [583/612] Processing file: 8FJL_1_a1-b1.fasta
#   Input sequence length: 104
#   Found 16 samples
#   Median metrics: perplexity=1.2853, recovery=0.4118, edit_dist=50.0000, sc_score=0.9899
#   ✓ Processed successfully
#
# [584/612] Processing file: 8FJL_1_a2-b2.fasta
#   Input sequence length: 120
#   Found 16 samples
#   Median metrics: perplexity=1.2786, recovery=0.4830, edit_dist=58.5000, sc_score=0.9913
#   ✓ Processed successfully
#
# [585/612] Processing file: 8FJL_1_a3-b3.fasta
#   Input sequence length: 80
#   Found 16 samples
#   Median metrics: perplexity=1.2719, recovery=0.4744, edit_dist=37.0000, sc_score=0.9866
#   ✓ Processed successfully
#
# [586/612] Processing file: 8FKP_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.3555, recovery=0.3333, edit_dist=39.0000, sc_score=0.6223
#   ✓ Processed successfully
#
# [587/612] Processing file: 8FKQ_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.4021, recovery=0.3333, edit_dist=41.0000, sc_score=0.6500
#   ✓ Processed successfully
#
# [588/612] Processing file: 8FKR_1_L2.fasta
#   Input sequence length: 69
#   Found 15 samples
#   Median metrics: perplexity=1.4022, recovery=0.2899, edit_dist=40.0000, sc_score=0.6390
#   ✓ Processed successfully
#
# [589/612] Processing file: 8FKS_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.3887, recovery=0.3188, edit_dist=39.5000, sc_score=0.6058
#   ✓ Processed successfully
#
# [590/612] Processing file: 8FKT_1_L2.fasta
#   Input sequence length: 69
#   Found 15 samples
#   Median metrics: perplexity=1.3835, recovery=0.3478, edit_dist=40.0000, sc_score=0.6804
#   ✓ Processed successfully
#
# [591/612] Processing file: 8FKU_1_L2.fasta
#   Input sequence length: 69
#   Found 15 samples
#   Median metrics: perplexity=1.3949, recovery=0.3768, edit_dist=39.0000, sc_score=0.5642
#   ✓ Processed successfully
#
# [592/612] Processing file: 8FKV_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.4146, recovery=0.3550, edit_dist=39.5000, sc_score=0.5573
#   ✓ Processed successfully
#
# [593/612] Processing file: 8FKW_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.4309, recovery=0.3623, edit_dist=40.0000, sc_score=0.5722
#   ✓ Processed successfully
#
# [594/612] Processing file: 8FKX_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.3817, recovery=0.3623, edit_dist=37.5000, sc_score=0.6485
#   ✓ Processed successfully
#
# [595/612] Processing file: 8FKY_1_L2.fasta
#   Input sequence length: 69
#   Found 16 samples
#   Median metrics: perplexity=1.4189, recovery=0.3478, edit_dist=39.5000, sc_score=0.6240
#   ✓ Processed successfully
#
# [596/612] Processing file: 8FKZ_1_L2.fasta
#   Input sequence length: 68
#   Found 16 samples
#   Median metrics: perplexity=1.3587, recovery=0.3456, edit_dist=39.0000, sc_score=0.6395
#   ✓ Processed successfully
#
# [597/612] Processing file: 8FL2_1_L2.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.4132, recovery=0.2986, edit_dist=45.0000, sc_score=0.5977
#   ✓ Processed successfully
#
# [598/612] Processing file: 8FL6_1_L2.fasta
#   Input sequence length: 72
#   Found 14 samples
#   Median metrics: perplexity=1.3788, recovery=0.2917, edit_dist=47.0000, sc_score=0.5183
#   ✓ Processed successfully
#
# [599/612] Processing file: 8FLA_1_L2.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.4013, recovery=0.2986, edit_dist=45.0000, sc_score=0.5975
#   ✓ Processed successfully
#
# [600/612] Processing file: 8FLD_1_L2.fasta
#   Input sequence length: 72
#   Found 16 samples
#   Median metrics: perplexity=1.3504, recovery=0.2917, edit_dist=46.5000, sc_score=0.5735
#   ✓ Processed successfully
#
# [601/612] Processing file: 8G9Z_1_E.fasta
#   Input sequence length: 87
#   Found 16 samples
#   Median metrics: perplexity=1.2048, recovery=0.5765, edit_dist=35.5000, sc_score=0.8908
#   ✓ Processed successfully
#
# [602/612] Processing file: 8GS2_1_R-D.fasta
#   Input sequence length: 61
#   Found 16 samples
#   Median metrics: perplexity=1.5659, recovery=0.4333, edit_dist=30.5000, sc_score=0.9125
#   ✓ Processed successfully
#
# [603/612] Processing file: 8GWB_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2713, recovery=0.3462, edit_dist=26.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [604/612] Processing file: 8GWE_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2440, recovery=0.3462, edit_dist=25.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [605/612] Processing file: 8GWF_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2427, recovery=0.3462, edit_dist=25.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [606/612] Processing file: 8GWG_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2427, recovery=0.3462, edit_dist=25.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [607/612] Processing file: 8GWI_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2427, recovery=0.3462, edit_dist=25.0000, sc_score=1.0000
#   ✓ Processed successfully
#
# [608/612] Processing file: 8GWN_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2667, recovery=0.4712, edit_dist=24.0000, sc_score=0.9324
#   ✓ Processed successfully
#
# [609/612] Processing file: 8GWO_1_J-I.fasta
#   Input sequence length: 52
#   Found 16 samples
#   Median metrics: perplexity=1.2748, recovery=0.2115, edit_dist=27.0000, sc_score=0.9353
#   ✓ Processed successfully
#
# [610/612] Processing file: 8HMY_1_T.fasta
#   Input sequence length: 90
#   Found 16 samples
#   Median metrics: perplexity=1.1653, recovery=0.5889, edit_dist=36.5000, sc_score=0.5794
#   ✓ Processed successfully
#
# [611/612] Processing file: 8I3Q_1_C.fasta
#   Input sequence length: 95
#   Found 16 samples
#   Median metrics: perplexity=1.4922, recovery=0.4947, edit_dist=43.5000, sc_score=0.7030
#   ✓ Processed successfully
#
# [612/612] Processing file: 8JOZ_1_B.fasta
#   Input sequence length: 79
#   Found 16 samples
#   Median metrics: perplexity=1.1795, recovery=0.5507, edit_dist=31.0000, sc_score=0.7637
#   ✓ Processed successfully
#
# === Processing Completed ===
# Total files: 612
# Successfully processed: 603
# Failed: 9
# Results saved to: ./data/fullatten03_s4.txt
#
# Results preview (first 5 lines):
#   63 1.2319 0.7381 16.0000 0.6968
#   63 1.1531 0.7619 15.0000 0.9318
#   33 1.1933 0.5312 15.0000 0.6284
#   62 1.1919 0.6935 17.0000 0.2216
#   62 1.1978 0.7339 15.0000 0.3626
#   ... (total 603 lines)
#
# === Validate Output Format ===
# Total lines: 603
# Line 1: length=63, perplexity=1.2319, recovery=0.7381, edit_dist=16.0, sc_score=0.6968
# Line 2: length=63, perplexity=1.1531, recovery=0.7619, edit_dist=15.0, sc_score=0.9318
# Line 3: length=33, perplexity=1.1933, recovery=0.5312, edit_dist=15.0, sc_score=0.6284

# %%
### Single seed RNA Design Data Analysis Script###
def analyze_rna_data(filename="./data/fullatten_s42.txt"):#Just change the filename or path to analyze different data files
    """
    Read our .fasta files,
    length (int)
    recovery (float)
    scc (float)
    """
    if not os.path.exists(filename):
        print(f"Error: '{filename}' is not found in the current directory.")
        return

    # Create data buckets for three length ranges
    range_small = []  # 0-100 nt
    range_medium = [] # 101-200 nt
    range_large = []  # >200 nt

    with open(filename, 'r') as f:
        for line in f:
            # Try to parse each line
            try:
                parts = line.strip().split()
                # Ensure the line has enough data columns
                if len(parts) >= 5:
                    length = int(parts[0])
                    recovery = float(parts[2])
                    scc = float(parts[4])
                    if length <= 100:
                        range_small.append([recovery, scc])
                    elif 100 < length <= 200:
                        range_medium.append([recovery, scc])
                    else: # length > 200
                        range_large.append([recovery, scc])
            except (ValueError, IndexError):
                continue

    # Define a function to calculate statistics and return a dictionary
    def calculate_statistics(data):
        if not data:
            return {
                "mean_recovery": 0.0, "median_recovery": 0.0,
                "mean_scc": 0.0, "median_scc": 0.0
            }

        data_np = np.array(data)
        recoveries = data_np[:, 0]
        sccs = data_np[:, 1]
        
        return {
            "mean_recovery": np.mean(recoveries),
            "median_recovery": np.median(recoveries),
            "mean_scc": np.mean(sccs),
            "median_scc": np.median(sccs)
        }

    stats_small = calculate_statistics(range_small)
    stats_medium = calculate_statistics(range_medium)
    stats_large = calculate_statistics(range_large)

    print(f"Reading {filename} ...")
    print("           & Recovery (0-100) & Recovery (100-200) & Recovery (>200) & SC Score (0-100) & SC Score (100-200) & SC Score (>200)")
    
    mean_line = (
        f"Average:    & {stats_small['mean_recovery']:.3f} & {stats_medium['mean_recovery']:.3f} & {stats_large['mean_recovery']:.3f} & "
        f"{stats_small['mean_scc']:.3f} & {stats_medium['mean_scc']:.3f} & {stats_large['mean_scc']:.3f}"
    )

    median_line = (
        f"Median:     & {stats_small['median_recovery']:.3f} & {stats_medium['median_recovery']:.3f} & {stats_large['median_recovery']:.3f} & "
        f"{stats_small['median_scc']:.3f} & {stats_medium['median_scc']:.3f} & {stats_large['median_scc']:.3f}"
    )

    print(mean_line)
    print(median_line)


if __name__ == "__main__":
    analyze_rna_data()
# Out:
# Reading ./data/fullatten_s42.txt ...
#            & Recovery (0-100) & Recovery (100-200) & Recovery (>200) & SC Score (0-100) & SC Score (100-200) & SC Score (>200)
# Average:    & 0.495 & 0.453 & 0.710 & 0.683 & 0.618 & 0.408
# Median:     & 0.500 & 0.475 & 0.680 & 0.710 & 0.560 & 0.385

# %%
def analyze_mean_stability(filenames: List[str]):
    for filename in filenames:
        if not os.path.exists(filename):
            print(f"Error: '{filename}' is not found in the current directory.")
            return
###### We will take the Average for each file, and then compute the mean ± standard deviation across those average values.######
    small_recovery_means, medium_recovery_means, large_recovery_means = [], [], []
    small_scc_means, medium_scc_means, large_scc_means = [], [], []

    for filename in filenames:
        range_small, range_medium, range_large = [], [], [] 
        with open(filename, 'r') as f:
            for line in f:
                try:
                    parts = line.strip().split()
                    if len(parts) >= 5:
                        length = int(parts[0])
                        recovery = float(parts[2])
                        scc = float(parts[4])
                        
                        if length <= 100:
                            range_small.append([recovery, scc])
                        elif 100 < length <= 200:
                            range_medium.append([recovery, scc])
                        else:
                            range_large.append([recovery, scc])
                except (ValueError, IndexError):
                    continue

        if range_small:
            small_recovery_means.append(np.mean(np.array(range_small)[:, 0]))
            small_scc_means.append(np.mean(np.array(range_small)[:, 1]))
        if range_medium:
            medium_recovery_means.append(np.mean(np.array(range_medium)[:, 0]))
            medium_scc_means.append(np.mean(np.array(range_medium)[:, 1]))
        if range_large:
            large_recovery_means.append(np.mean(np.array(range_large)[:, 0]))
            large_scc_means.append(np.mean(np.array(range_large)[:, 1]))

    def calculate_stats_of_means(means_list):
        if not means_list:
            return 0.0, 0.0
        return np.mean(means_list), np.std(means_list)

    mean_rec_small, std_rec_small = calculate_stats_of_means(small_recovery_means)
    mean_rec_medium, std_rec_medium = calculate_stats_of_means(medium_recovery_means)
    mean_rec_large, std_rec_large = calculate_stats_of_means(large_recovery_means)
    
    mean_scc_small, std_scc_small = calculate_stats_of_means(small_scc_means)
    mean_scc_medium, std_scc_medium = calculate_stats_of_means(medium_scc_means)
    mean_scc_large, std_scc_large = calculate_stats_of_means(large_scc_means)

    print("\n--- Multiple Seed Experiments [Average] Stability Analysis ---")
    print(f"Reading {', '.join(filenames)}...")

    result_line_recovery = (
        f"Recovery (Mean): & "
        f"{mean_rec_small:.3f} ± {std_rec_small:.3f} & "
        f"{mean_rec_medium:.3f} ± {std_rec_medium:.3f} & "
        f"{mean_rec_large:.3f} ± {std_rec_large:.3f}"
    )
    result_line_scc = (
        f"SC Score (Mean): & "
        f"{mean_scc_small:.3f} ± {std_scc_small:.3f} & "
        f"{mean_scc_medium:.3f} ± {std_scc_medium:.3f} & "
        f"{mean_scc_large:.3f} ± {std_scc_large:.3f}"
    )

    print("Average               & 0-100 nt     & 100-200 nt     & >200 nt")
    print("-" * 90)
    print(result_line_recovery)
    print(result_line_scc)

def analyze_median_stability(filenames: List[str]):
###### We will take the median for each file, and then compute the mean ± standard deviation across those median values.######
    for filename in filenames:
        if not os.path.exists(filename):
            print(f"Error: '{filename}' is not found in the current directory.")
            return

    small_recovery_medians, medium_recovery_medians, large_recovery_medians = [], [], []
    small_scc_medians, medium_scc_medians, large_scc_medians = [], [], []

    for filename in filenames:
        range_small, range_medium, range_large = [], [], []
        
        with open(filename, 'r') as f:
            for line in f:
                try:
                    parts = line.strip().split()
                    if len(parts) >= 5:
                        length = int(parts[0])
                        recovery = float(parts[2])
                        scc = float(parts[4])
                        
                        if length <= 100:
                            range_small.append([recovery, scc])
                        elif 100 < length <= 200:
                            range_medium.append([recovery, scc])
                        else:
                            range_large.append([recovery, scc])
                except (ValueError, IndexError):
                    continue
        
        if range_small:
            small_recovery_medians.append(np.median(np.array(range_small)[:, 0]))
            small_scc_medians.append(np.median(np.array(range_small)[:, 1]))
        if range_medium:
            medium_recovery_medians.append(np.median(np.array(range_medium)[:, 0]))
            medium_scc_medians.append(np.median(np.array(range_medium)[:, 1]))
        if range_large:
            large_recovery_medians.append(np.median(np.array(range_large)[:, 0]))
            large_scc_medians.append(np.median(np.array(range_large)[:, 1]))

    def calculate_stats_of_medians(medians_list):
        if not medians_list:
            return 0.0, 0.0
        return np.mean(medians_list), np.std(medians_list)

    mean_rec_small, std_rec_small = calculate_stats_of_medians(small_recovery_medians)
    mean_rec_medium, std_rec_medium = calculate_stats_of_medians(medium_recovery_medians)
    mean_rec_large, std_rec_large = calculate_stats_of_medians(large_recovery_medians)
    
    mean_scc_small, std_scc_small = calculate_stats_of_medians(small_scc_medians)
    mean_scc_medium, std_scc_medium = calculate_stats_of_medians(medium_scc_medians)
    mean_scc_large, std_scc_large = calculate_stats_of_medians(large_scc_medians)

    print("\n--- Multiple Seed Experiments [Median] Stability Analysis ---")
    print(f"Reading {', '.join(filenames)} ...")

    result_line_recovery = (
        f"Recovery (Median): & "
        f"{mean_rec_small:.3f} ± {std_rec_small:.3f} & "
        f"{mean_rec_medium:.3f} ± {std_rec_medium:.3f} & "
        f"{mean_rec_large:.3f} ± {std_rec_large:.3f}"
    )
    result_line_scc = (
        f"SC Score (Median): & "
        f"{mean_scc_small:.3f} ± {std_scc_small:.3f} & "
        f"{mean_scc_medium:.3f} ± {std_scc_medium:.3f} & "
        f"{mean_scc_large:.3f} ± {std_scc_large:.3f}"
    )

    print("Median                & 0-100 nt     & 100-200 nt     & >200 nt")
    print("-" * 90)
    print(result_line_recovery)
    print(result_line_scc)


if __name__ == "__main__":
    files_to_analyze = [
        "./data/fullatten_s0.txt", 
        "./data/fullatten_s1.txt", 
        "./data/fullatten03_s4.txt"
    ]
    
    analyze_mean_stability(files_to_analyze)
    analyze_median_stability(files_to_analyze)
# Out:
# --- Multiple Seed Experiments [Average] Stability Analysis ---
# Reading ./data/fullatten_s0.txt, ./data/fullatten_s1.txt, ./data/fullatten03_s4.txt...
# Average               & 0-100 nt     & 100-200 nt     & >200 nt
# ------------------------------------------------------------------------------------------
# Recovery (Mean): & 0.498 ± 0.017 & 0.481 ± 0.035 & 0.730 ± 0.004
# SC Score (Mean): & 0.692 ± 0.008 & 0.635 ± 0.019 & 0.418 ± 0.009
#
# --- Multiple Seed Experiments [Median] Stability Analysis ---
# Reading ./data/fullatten_s0.txt, ./data/fullatten_s1.txt, ./data/fullatten03_s4.txt ...
# Median                & 0-100 nt     & 100-200 nt     & >200 nt
# ------------------------------------------------------------------------------------------
# Recovery (Median): & 0.502 ± 0.007 & 0.441 ± 0.017 & 0.707 ± 0.006
# SC Score (Median): & 0.716 ± 0.014 & 0.624 ± 0.024 & 0.410 ± 0.011
